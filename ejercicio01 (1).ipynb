# %% [markdown]
# # Ejercicio 1 - Funciones Lambda
# Definición y uso de funciones lambda en Python.

# %% [markdown]
# ## a. Lambda: ¿es múltiplo de 3?

# %%
es_multiplo_3 = lambda n: n % 3 == 0

print(es_multiplo_3(9))   
print(es_multiplo_3(10)) 
print(es_multiplo_3(0))
# Out:
# True
# False
# True

# %% [markdown]
# ## b. Lambda: cubo de un número

# %%
cubo = lambda n: n ** 3

print(cubo(3))  
print(cubo(5))  
print(cubo(-2))
# Out:
# 27
# 125
# -8

# %% [markdown]
# ## c. Lambda: producto de dos números

# %%
producto = lambda a, b: a * b

print(producto(4, 5))   
print(producto(3, -2))
# Out:
# 20
# -6

# %% [markdown]
# ## d. Lambda: mayor de dos números

# %%
mayor = lambda a, b: a if a > b else b

print(mayor(7, 3))
print(mayor(2, 10))  
print(mayor(5, 5))
# Out:
# 7
# 10
# 5

# %% [markdown]
# ## e. Lambda: ¿empieza con 'A' o 'a'?

# %%
empieza_con_a = lambda palabra: palabra[0].lower() == 'a'

print(empieza_con_a('Avión'))    
print(empieza_con_a('árbol'))    
print(empieza_con_a('Casa'))
# Out:
# True
# False
# False

# %% [markdown]
# ## f. Lambda: Celsius a Fahrenheit

# %%
celsius_a_fahrenheit = lambda c: c * 9/5 + 32

print(celsius_a_fahrenheit(0))    
print(celsius_a_fahrenheit(100))  
print(celsius_a_fahrenheit(37))
# Out:
# 32.0
# 212.0
# 98.6

# %% [markdown]
# ## g. Lista de tres lambdas y aplicación al número ingresado por el usuario

# %%
operaciones = [
    lambda n: n * 2,       
    lambda n: n + 10,      
    lambda n: n ** 2       
]

numero = int(input('Ingrese un número: '))

for operacion in operaciones:
    print(operacion(numero))
# Out:
# Ingrese un número:  5
# 10
# 15
# 25
